# %% [markdown]
# # Exercise Pandas

# %% [markdown]
# ### For the dataset “Cars csv", write a Pandas program to:
#
# ### Q1- Show the first 10 rows and get the number of rows, columns, datatype for each column

# %%
import pandas as pd

df = pd.read_csv("Cars.csv")

# show the first 10 rows
print(df.head(10))
# Out:
#    YEAR        Make                            Model        Size  (kW)  \
# 0  2012  MITSUBISHI                           i-MiEV  SUBCOMPACT    49
# 1  2012      NISSAN                             LEAF    MID-SIZE    80
# 2  2013        FORD                   FOCUS ELECTRIC     COMPACT   107
# 3  2013  MITSUBISHI                           i-MiEV  SUBCOMPACT    49
# 4  2013      NISSAN                             LEAF    MID-SIZE    80
# 5  2013       SMART  FORTWO ELECTRIC DRIVE CABRIOLET  TWO-SEATER    35
# 6  2013       SMART      FORTWO ELECTRIC DRIVE COUPE  TWO-SEATER    35
# 7  2013       TESLA         MODEL S (40 kWh battery)   FULL-SIZE   270
# 8  2013       TESLA         MODEL S (60 kWh battery)   FULL-SIZE   270
# 9  2013       TESLA         MODEL S (85 kWh battery)   FULL-SIZE   270
#
#   Unnamed: 5 TYPE  CITY (kWh/100 km)  HWY (kWh/100 km)  COMB (kWh/100 km)  \
# 0         A1    B               16.9              21.4               18.7
# ...

# %%
# Get the number of rows, columns, datatype for each column
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53 entries, 0 to 52
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   YEAR               53 non-null     int64
#  1   Make               53 non-null     object
#  2   Model              53 non-null     object
#  3   Size               53 non-null     object
#  4   (kW)               53 non-null     int64
#  5   Unnamed: 5         53 non-null     object
#  6   TYPE               53 non-null     object
#  7   CITY (kWh/100 km)  53 non-null     float64
#  8   HWY (kWh/100 km)   53 non-null     float64
#  9   COMB (kWh/100 km)  53 non-null     float64
#  10  CITY (Le/100 km)   53 non-null     float64
#  11  HWY (Le/100 km)    53 non-null     float64
#  12  COMB (Le/100 km)   53 non-null     float64
#  13  (g/km)             53 non-null     int64
#  14  RATING             19 non-null     float64
#  15  (km)               53 non-null     int64
# ...

# %% [markdown]
# ### Q2- Compute the descriptive statistics of each column

# %%
df.describe()
# Out:
#               YEAR        (kW)  CITY (kWh/100 km)  HWY (kWh/100 km)  \
# count    53.000000   53.000000           53.00000         53.000000
# mean   2014.735849  190.622642           19.64717         21.633962
# std       1.227113  155.526429            3.00100          1.245753
# min    2012.000000   35.000000           15.20000         18.800000
# 25%    2014.000000   80.000000           17.00000         20.800000
# 50%    2015.000000  107.000000           19.00000         21.700000
# 75%    2016.000000  283.000000           22.40000         22.500000
# max    2016.000000  568.000000           23.90000         23.300000
#
#        COMB (kWh/100 km)  CITY (Le/100 km)  HWY (Le/100 km)  COMB (Le/100 km)  \
# count          53.000000         53.000000        53.000000         53.000000
# mean           20.541509          2.207547         2.422642          2.301887
# std             1.979455          0.344656         0.143636          0.212576
# ...

# %% [markdown]
# ### Q3- Check if the DataFrame has any missing values

# %%
missing = df.isnull()
print(missing)
# Out:
#      YEAR   Make  Model   Size   (kW)  Unnamed: 5   TYPE  CITY (kWh/100 km)  \
# 0   False  False  False  False  False       False  False              False
# 1   False  False  False  False  False       False  False              False
# 2   False  False  False  False  False       False  False              False
# 3   False  False  False  False  False       False  False              False
# 4   False  False  False  False  False       False  False              False
# 5   False  False  False  False  False       False  False              False
# 6   False  False  False  False  False       False  False              False
# 7   False  False  False  False  False       False  False              False
# 8   False  False  False  False  False       False  False              False
# 9   False  False  False  False  False       False  False              False
# 10  False  False  False  False  False       False  False              False
# ...

# %% [markdown]
# ### Q4- Count the number of missing values in each column

# %%
missing.sum()
# Out:
# YEAR                  0
# Make                  0
# Model                 0
# Size                  0
# (kW)                  0
# Unnamed: 5            0
# TYPE                  0
# CITY (kWh/100 km)     0
# HWY (kWh/100 km)      0
# COMB (kWh/100 km)     0
# CITY (Le/100 km)      0
# HWY (Le/100 km)       0
# COMB (Le/100 km)      0
# (g/km)                0
# RATING               34
# (km)                  0
# TIME (h)              0
# dtype: int64

# %% [markdown]
# ### Q5- Replace missing values with their respective median

# %%
df["RATING"].fillna(df["RATING"].mean(), inplace = True)
print(df.isnull().sum().sum())
# Out:
# 0

# %% [markdown]
# ### Q6- Compute correlation between features and plot their scatter diagram. What are the conclusions ?

# %%
# compute correlation matrix
corr = df.corr()
print(corr)
# Out:
#                        YEAR      (kW)  CITY (kWh/100 km)  HWY (kWh/100 km)  \
# YEAR               1.000000  0.303071           0.046792         -0.264488
# (kW)               0.303071  1.000000           0.827555          0.046083
# CITY (kWh/100 km)  0.046792  0.827555           1.000000          0.442151
# HWY (kWh/100 km)  -0.264488  0.046083           0.442151          1.000000
# COMB (kWh/100 km) -0.034193  0.706847           0.965258          0.657155
# CITY (Le/100 km)   0.045727  0.823125           0.996966          0.447289
# HWY (Le/100 km)   -0.270912  0.047220           0.437810          0.986524
# COMB (Le/100 km)  -0.034914  0.721353           0.966911          0.623550
# (g/km)                  NaN       NaN                NaN               NaN
# RATING                  NaN       NaN                NaN               NaN
# (km)               0.234407  0.894615           0.906960          0.166217
# ...

# %%
## ==> NaN values in corr matrix because of constant features
df.std()
# Out:
# C:\Users\Olfa\AppData\Local\Temp\ipykernel_144\3390915376.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.std()
# YEAR                   1.227113
# (kW)                 155.526429
# CITY (kWh/100 km)      3.001000
# HWY (kWh/100 km)       1.245753
# COMB (kWh/100 km)      1.979455
# CITY (Le/100 km)       0.344656
# HWY (Le/100 km)        0.143636
# COMB (Le/100 km)       0.212576
# (g/km)                 0.000000
# RATING                 0.000000
# (km)                 141.426352
# TIME (h)               2.991036
# dtype: float64

# %%
# ==> two features have constant values, we drop them 
df.drop(["RATING", "(g/km)"], axis=1, inplace = True)
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53 entries, 0 to 52
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   YEAR               53 non-null     int64
#  1   Make               53 non-null     object
#  2   Model              53 non-null     object
#  3   Size               53 non-null     object
#  4   (kW)               53 non-null     int64
#  5   Unnamed: 5         53 non-null     object
#  6   TYPE               53 non-null     object
#  7   CITY (kWh/100 km)  53 non-null     float64
#  8   HWY (kWh/100 km)   53 non-null     float64
#  9   COMB (kWh/100 km)  53 non-null     float64
#  10  CITY (Le/100 km)   53 non-null     float64
#  11  HWY (Le/100 km)    53 non-null     float64
#  12  COMB (Le/100 km)   53 non-null     float64
#  13  (km)               53 non-null     int64
#  14  TIME (h)           53 non-null     int64
# dtypes: float64(6), int64(4), object(5)
# ...

# %%
# compute correlation matrix
corr = df.corr()
print(corr)
# Out:
#                        YEAR      (kW)  CITY (kWh/100 km)  HWY (kWh/100 km)  \
# YEAR               1.000000  0.303071           0.046792         -0.264488
# (kW)               0.303071  1.000000           0.827555          0.046083
# CITY (kWh/100 km)  0.046792  0.827555           1.000000          0.442151
# HWY (kWh/100 km)  -0.264488  0.046083           0.442151          1.000000
# COMB (kWh/100 km) -0.034193  0.706847           0.965258          0.657155
# CITY (Le/100 km)   0.045727  0.823125           0.996966          0.447289
# HWY (Le/100 km)   -0.270912  0.047220           0.437810          0.986524
# COMB (Le/100 km)  -0.034914  0.721353           0.966911          0.623550
# (km)               0.234407  0.894615           0.906960          0.166217
# TIME (h)           0.139391  0.757326           0.806459          0.316639
#
#                    COMB (kWh/100 km)  CITY (Le/100 km)  HWY (Le/100 km)  \
# ...

# %%
# plot the scatter betwwen features
# https://pandas.pydata.org/pandas-docs/stable/user_guide/visualization.html#scatter-plot

from pandas.plotting import scatter_matrix
scatter_matrix(df, figsize=(15, 15));

# %%
## ==> there are highly correlated features: 
print(corr > 0.97)
# Out:
#                     YEAR   (kW)  CITY (kWh/100 km)  HWY (kWh/100 km)  \
# YEAR                True  False              False             False
# (kW)               False   True              False             False
# CITY (kWh/100 km)  False  False               True             False
# HWY (kWh/100 km)   False  False              False              True
# COMB (kWh/100 km)  False  False              False             False
# CITY (Le/100 km)   False  False               True             False
# HWY (Le/100 km)    False  False              False              True
# COMB (Le/100 km)   False  False              False             False
# (km)               False  False              False             False
# TIME (h)           False  False              False             False
#
#                    COMB (kWh/100 km)  CITY (Le/100 km)  HWY (Le/100 km)  \
# YEAR                           False             False            False
# ...
